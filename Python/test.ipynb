# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.Series([[5, 7, 8, 8.5, 9, 10, 3.5, 0.5],
                  [6, 8, 9, 9.5, 10, 11, 4.5, 1.5]])

'''
几组数据就用几组标签
'''
plt.boxplot(data, labels=["group1","group2"])
plt.ylabel("Value")
plt.show()
# Out:
# C:\Users\learn\AppData\Local\Temp\ipykernel_14704\3627066788.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=["group1","group2"])
